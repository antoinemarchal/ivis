# %% [markdown]
# # Noise (& beam) response
#
# ## Download
#
# You can download the data directory `data_tutorials` using:
#
# ```bash
# wget https://www.mso.anu.edu.au/~amarchal/shared/ivis/data_tutorials.zip
# unzip data_tutorials.zip -d data_tutorials
# rm data_tutorials.zip
# ```
#
# Kindly provided by Enrico Di Teodoro (UniFI) and Karlie Noon (RSAA/ANU).
#
# ## Method
# <div style="text-align: justify;">
#
# > To characterize the **image-domain response of the noise** in the visibility data, we performed imaging on a single realization constructed using the <code>SIGMA</code> array available in the Measurement Set.
# We then computed the one-dimensional spatial **power spectrum** <em>P(k)</em> of the resulting image.
# >
# > Note that to fully characterize <em>P(k)</em>, we recommend repeating this procedure over **multiple random realizations** (typically at least 20) and averaging the resulting spectra.
#
# </div>

# %% [markdown]
# ### Read data

# %%
import glob
from tqdm import tqdm as tqdm

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
from astropy.io import fits
from radio_beam import Beam
from astropy import units as u
from reproject import reproject_interp

from ivis.io import DataProcessor
from ivis.imager import Imager3D
from ivis.logger import logger
from ivis.utils import dutils, fourier

from ivis.models import ClassicIViS3D

path_ms = "./data_tutorials/ivis_data/msl_mw/" #directory of measurement sets    
path_beams = "./data_tutorials/ivis_data/BEAMS/" #directory of primary beams
path_sd = None #path single-dish data
pathout = "./data_tutorials/ivis_data/" #path where data will be packaged and stored

#REF WCS INPUT USER
filename = "./data_tutorials/ivis_data/MW-C10_mom0th_NHI.fits"
target_header = fits.open(filename)[0].header
shape = (target_header["NAXIS2"],target_header["NAXIS1"])
    
#create data processor
data_processor = DataProcessor(path_ms, path_beams, path_sd, pathout)

# pre-compute pb and interpolation grids — this can be commented after first compute
logger.disabled = True
data_processor.compute_pb_and_grid(target_header, fitsname_pb="reproj_pb.fits", fitsname_grid="grid_interp.fits") 
logger.disabled = False

pb, grid = data_processor.read_pb_and_grid(fitsname_pb="reproj_pb.fits", fitsname_grid="grid_interp.fits")

#Dummy sd array
sd = np.zeros(shape)
#Dummy Beam sd
beam_sd = Beam(1*u.deg, 1*u.deg, 1.e-12*u.deg)
# Out:
# [2025-08-16 02:50:07 UTC] [IViS] [info] [Initialize DataProcessor ]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:02<00:00,  2.15it/s]

# %%
# -------------------
# Read visibilities into VisIData dataclass
# -------------------
vis_data = data_processor.read_vis_visidata(
    uvmin=0.0,
    uvmax=np.inf,
    # target_channel=0,
    chan_sel=slice(0, 1),
    keep_autocorr=False,
    prefer_weight_spectrum=False,
    n_workers=4,
)
# Out:
# [2025-08-16 02:50:50 UTC] [IViS] [info] [BLOCK] Loading 5 beam(s) from: ./data_tutorials/ivis_data/msl_mw/
# [2025-08-16 02:50:50 UTC] [IViS] [info] [ORDER PLAN] beam 00 -> MW-C10_1_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info] [ORDER PLAN] beam 01 -> MW-C10_2_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info] [ORDER PLAN] beam 02 -> MW-C10_3_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info] [ORDER PLAN] beam 03 -> MW-C10_4_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info] [ORDER PLAN] beam 04 -> MW-C10_5_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info] [BLOCK] Parallel read with 4 workers (order-preserving)
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Opening: ./data_tutorials/ivis_data/msl_mw/MW-C10_3_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Opening: ./data_tutorials/ivis_data/msl_mw/MW-C10_2_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Opening: ./data_tutorials/ivis_data/msl_mw/MW-C10_1_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Opening: ./data_tutorials/ivis_data/msl_mw/MW-C10_4_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Done: MW-C10_1_MW_chan_-32kms.ms  rows=626313
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Opening: ./data_tutorials/ivis_data/msl_mw/MW-C10_5_MW_chan_-32kms.ms
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Done: MW-C10_2_MW_chan_-32kms.ms  rows=1068720
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Done: MW-C10_4_MW_chan_-32kms.ms  rows=1140552
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Done: MW-C10_3_MW_chan_-32kms.ms  rows=1140552
# [2025-08-16 02:50:50 UTC] [IViS] [info]     [MS] Done: MW-C10_5_MW_chan_-32kms.ms  rows=1098366
# [2025-08-16 02:50:51 UTC] [IViS] [info] [BLOCK] Done: nchan=1, nbeam=5, nvis_max=1140552
# [2025-08-16 02:50:51 UTC] [IViS] [info] [ORDER CHECK] beam 00 -> MW-C10_1_MW_chan_-32kms.ms
# [2025-08-16 02:50:51 UTC] [IViS] [info] [ORDER CHECK] beam 01 -> MW-C10_2_MW_chan_-32kms.ms
# [2025-08-16 02:50:51 UTC] [IViS] [info] [ORDER CHECK] beam 02 -> MW-C10_3_MW_chan_-32kms.ms
# [2025-08-16 02:50:51 UTC] [IViS] [info] [ORDER CHECK] beam 03 -> MW-C10_4_MW_chan_-32kms.ms
# [2025-08-16 02:50:51 UTC] [IViS] [info] [ORDER CHECK] beam 04 -> MW-C10_5_MW_chan_-32kms.ms

# %% [markdown]
# ### Empty sky model

# %%
sky_model = np.zeros(shape, dtype=np.float32)

# %% [markdown]
# ### Set PB=1 (depends on the response you want: (A*N) or N

# %%
#pb = np.full(pb.shape,1)

# %% [markdown]
# ### Simulated visibilities (using IViS forward model)

# %%
#Model visibilities with IVis forward single frequency model
image_processor = Imager3D(vis_data,      # visibilities
                         pb,            # array of primary beams
                         grid,          # array of interpolation grids
                         None,            # single dish data in unit of Jy/arcsec^2
                         None,       # beam of single-dish data in radio_beam format
                         target_header, # header on which to image the data
                         sky_model,   # init array of parameters
                         0,       # maximum number of iterations
                         0,     # hyper-parameter single-dish
                         False,    # impose a positivity constaint
                         0,        # device: 0 is GPU; "cpu" is CPU
                         0,
                         beam_workers=1)

model = ClassicIViS3D()
model_vis =  image_processor.forward_model(model=model)
# Out:
# [2025-08-16 02:51:18 UTC] [IViS] [info] CUDA unavailable or invalid index; using CPU.
# [2025-08-16 02:51:18 UTC] [IViS] [info] CUDA unavailable or invalid index; using CPU.
# [2025-08-16 02:51:18 UTC] [IViS] [info] [Initialize Imager3D       ]
# [2025-08-16 02:51:18 UTC] [IViS] [info] Number of iterations to be performed by the optimizer: 0
# [2025-08-16 02:51:18 UTC] [IViS] [warning] lambda_sd = 0 — No short-spacing correction.
# [2025-08-16 02:51:18 UTC] [IViS] [info] Optimizer not bounded - Positivity == False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 17
#       2 image_processor = Imager3D(vis_data,      # visibilities
#       3                          pb,            # array of primary beams
#       4                          grid,          # array of interpolation grids
#    (...)
#      13                          0,
#      14                          beam_workers=1)
#      16 model = ClassicIViS3D()
# ---> 17 model_vis =  image_processor.forward_model(model=model)
#
# File ~/Desktop/Synthesis/ivis/ivis/imager.py:163, in Imager3D.forward_model(self, model)
#     160 pb_native = np.asarray(self.pb, dtype=np.float32)
#     161 grid_native = np.asarray(self.grid, dtype=np.float32)
# --> 163 return model.forward(
#     164     x=self.init_params,
#     165     vis_data=self.vis_data,
#     166     pb=pb_native,
#     167     device=self.device,
#     168     cell_size=cell_size.value,
#     169     grid_array=grid_native
#     170 )
#
# AttributeError: 'ClassicIViS3D' object has no attribute 'forward'

# %% [markdown]
# ### Adding realistic noise from the MeerKAT data beam

# %%
#Add noise
fact=1 #Scale the noise with this if needed
noise_real = np.random.normal(loc=0.0, scale=vis_data.sigma*fact)
noise_imag = np.random.normal(loc=0.0, scale=vis_data.sigma*fact)
noise = noise_real + 1j * noise_imag

# Add realistic thermal noise to the model visibilities
vis_data.data = model_vis + noise

# %% [markdown]
# ### Imaging using IViS

# %%
#user parameters
max_its = 20
lambda_sd = 0 #not relevant here
lambda_r = 1 #Control the strength of the Laplacian filtering
device = 0#"cpu" #0 is GPU and "cpu" is CPU
positivity = False #Set to False because noise fluctuates around 0

#Initial parameters (zero array)
init_params = np.zeros(shape, dtype=np.float32)

#create image processor
image_processor = Imager(vis_data,      # visibilities
                         pb,            # array of primary beams
                         grid,          # array of interpolation grids
                         sd,            # single dish data in unit of Jy/arcsec^2
                         beam_sd,       # beam of single-dish data in radio_beam format
                         target_header, # header on which to image the data
                         init_params,   # init array of parameters
                         max_its,       # maximum number of iterations
                         lambda_sd,     # hyper-parameter single-dish
                         positivity,    # impose a positivity constaint
                         device,        # device: 0 is GPU; "cpu" is CPU
                         beam_workers=1)
#get image
model = ClassicIViS(lambda_r=lambda_r)
noise = image_processor.process(model=model, units="Jy/arcsec^2") #"Jy/arcsec^2" or "K"
# Out:
# [2025-08-08 23:03:42 UTC] [IViS] [info] [Initialize Imager        ]
# [2025-08-08 23:03:42 UTC] [IViS] [info] Number of iterations to be performed by the optimizer: 20
# [2025-08-08 23:03:42 UTC] [IViS] [warning] lambda_sd = 0 - No short spacing correction (ignoring single dish data).
# [2025-08-08 23:03:42 UTC] [IViS] [warning] CUDA not available. Falling back on CPU.
# [2025-08-08 23:03:42 UTC] [IViS] [info] Nw <= 1 or None, using flat-sky NUFFT (no w-stacking).
# [2025-08-08 23:03:43 UTC] [IViS] [info] Starting optimisation (using LBFGS-B)
# [2025-08-08 23:03:43 UTC] [IViS] [info] Optimizer not bounded - Positivity == False
# [2025-08-08 23:03:49 UTC] [IViS] [info] [PID 79424] Total cost: 5.07580e+06
# [2025-08-08 23:03:54 UTC] [IViS] [info] [PID 79424] Total cost: 5.80533e+09
# [2025-08-08 23:03:56 UTC] [IViS] [info] [PID 79424] Total cost: 5.04857e+06
# [2025-08-08 23:03:58 UTC] [IViS] [info] [PID 79424] Total cost: 5.03069e+06
# [2025-08-08 23:04:00 UTC] [IViS] [info] [PID 79424] Total cost: 5.01906e+06
# [2025-08-08 23:04:03 UTC] [IViS] [info] [PID 79424] Total cost: 5.01016e+06
# [2025-08-08 23:04:05 UTC] [IViS] [info] [PID 79424] Total cost: 5.00429e+06
# [2025-08-08 23:04:08 UTC] [IViS] [info] [PID 79424] Total cost: 5.00027e+06
# [2025-08-08 23:04:10 UTC] [IViS] [info] [PID 79424] Total cost: 4.99691e+06
# [2025-08-08 23:04:12 UTC] [IViS] [info] [PID 79424] Total cost: 4.99440e+06
# [2025-08-08 23:04:13 UTC] [IViS] [info] [PID 79424] Total cost: 4.99219e+06
# [2025-08-08 23:04:15 UTC] [IViS] [info] [PID 79424] Total cost: 4.99066e+06
# [2025-08-08 23:04:19 UTC] [IViS] [info] [PID 79424] Total cost: 4.98936e+06
# [2025-08-08 23:04:22 UTC] [IViS] [info] [PID 79424] Total cost: 4.98820e+06
# [2025-08-08 23:04:25 UTC] [IViS] [info] [PID 79424] Total cost: 4.98733e+06
# [2025-08-08 23:04:28 UTC] [IViS] [info] [PID 79424] Total cost: 4.98658e+06
# [2025-08-08 23:04:30 UTC] [IViS] [info] [PID 79424] Total cost: 4.98595e+06
# [2025-08-08 23:04:31 UTC] [IViS] [info] [PID 79424] Total cost: 4.98533e+06
# [2025-08-08 23:04:34 UTC] [IViS] [info] [PID 79424] Total cost: 4.98489e+06
# [2025-08-08 23:04:36 UTC] [IViS] [info] [PID 79424] Total cost: 4.98451e+06
# [2025-08-08 23:04:39 UTC] [IViS] [info] [PID 79424] Total cost: 4.98418e+06
# [2025-08-08 23:04:41 UTC] [IViS] [info] [PID 79424] Total cost: 4.98389e+06
# [2025-08-08 23:04:41 UTC] [IViS] [warning] multiply by 2 for ASKAP.

# %%
#mean pb
filenames = sorted(glob.glob(path_beams+"*.fits"))
n_beams = len(filenames)
pb_all = np.zeros((n_beams,noise.shape[0],noise.shape[1]))
w = dutils.wcs2D(target_header)
for i in tqdm(np.arange(n_beams)):
    #open beam cube
    hdu_pb = fits.open(filenames[i])
    hdr_pb = hdu_pb[0].header
    pb2 = hdu_pb[0].data
    pb2[pb2 != pb2] = 0.
    w_pb = dutils.wcs2D(hdr_pb)
    pb2, footprint = reproject_interp((pb2,w_pb.to_header()), w.to_header(), shape)
    pb2[pb2 != pb2] = 0.
    pb_all += pb2
    pb_mean = np.nanmean(pb_all,0)
    pb_mean /= np.nanmax(pb_mean)    
    mask = np.where(pb_mean > 0.2, 1, np.nan)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:05<00:00,  1.05s/it]

# %%
#PLOT RESULT
fig = plt.figure(figsize=(5, 5))
ax = fig.add_axes([0.1,0.1,0.78,0.8], projection=w)
ax.set_xlabel(r"RA (deg)", fontsize=18.)
ax.set_ylabel(r"DEC (deg)", fontsize=18.)
img = ax.imshow(noise*mask, vmin=-3.5e-5, vmax=3.5e-5, origin="lower")
ax.contour(pb_mean, linestyles="--", levels=[0.2, 0.3], colors=["w","w"])
colorbar_ax = fig.add_axes([0.89, 0.11, 0.02, 0.78])
cbar = fig.colorbar(img, cax=colorbar_ax)
cbar.ax.tick_params(labelsize=14.)
cbar.set_label(r"$I$ (Jy/arcsec$^{2})$", fontsize=18.)
#    plt.savefig(pathout + 'ivis_result_cloud_MeerKAT.png', format='png', bbox_inches='tight', pad_inches=0.02, dpi=400)

# %% [markdown]
# ## Compute the P(k)

# %%
# Get tapper for apodization
tapper = fourier.apodize(0.97, shape)
# Reove the mean
field_zm = noise - np.mean(noise)
# Apply apodization function
field_zm_apod = field_zm * tapper

# Compute the 1D P(k)
ks, sps1d_n = fourier.powspec(field_zm_apod, reso=(target_header["CDELT2"]*u.deg).to(u.arcmin).value)

# %%
#Plot sps1D                                                                                                                                                                                                                                            
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.set_xscale('log')
ax.set_yscale('log')                                                                                                                                                                                                                                                                            
ax.plot(ks, sps1d_n, "-k")                                                                                                             
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"$k$ (arcmin$^{-1}$)", fontsize = 16)
ax.set_ylabel(r"$P(k)$ [(Jy/arcsec$^2$)$^2$]", fontsize = 16)
ax.xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
#plt.savefig('plot/SPS_.png', format='png', bbox_inches='tight', pad_inches=0.02)

# %% [markdown]
# ## Important note
#
# <div style="text-align: justify;">
#
# > It is useful to note that the effective beam response is inherently built into the imaging process. In this case, the sky model contains noise rather than a single point source, but the resulting beam still reflects the non-linear nature of the inversion.
# >
# > When modeling the power spectrum P(k), the effective beam—shaped by the regularization—acts *after* the noise, not before. This distinction is important when interpreting the noise properties of the reconstructed image.
# >
# > This is fundamentally different from a CLEAN approach, where the model is convolved with a chosen restoring beam, and the noise is added back afterward by gridding the residual visibilities.
#
# </div>

# %% [markdown]
# ## Compare with P(k) of signal

# %%
#Read data
vis_data_s = data_processor.read_vis_from_scratch(uvmin=0, uvmax=np.inf,
                                                 target_frequency=None,
                                                 target_channel=0,
                                                 extension=".ms",
                                                 blocks='single',
                                                 max_workers=1)

# create image processor
image_processor = Imager(vis_data_s,    # visibilities
                         pb,            # array of primary beams
                         grid,          # array of interpolation grids
                         sd,            # single dish data in unit of Jy/arcsec^2
                         beam_sd,       # beam of single-dish data in radio_beam format
                         target_header, # header on which to image the data
                         init_params,   # init array of parameters
                         max_its,       # maximum number of iterations
                         lambda_sd,     # hyper-parameter single-dish
                         positivity,    # impose a positivity constaint
                         device,        # device: 0 is GPU; "cpu" is CPU
                         beam_workers=1)
# choose model
model = ClassicIViS(lambda_r=1)
# get image
result = image_processor.process(model=model, units="Jy/arcsec^2") #"Jy/arcsec^2" or "K"
# Out:
# [2025-08-08 23:04:52 UTC] [IViS] [info] Processing single scheduling block.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Number of MS files = 5
# [2025-08-08 23:04:52 UTC] [IViS] [info] Reading MS files with single thread.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Processing file 1/5: ./data_tutorials/ivis_data/msl_mw/MW-C10_1_MW_chan_-32kms.ms
# [2025-08-08 23:04:52 UTC] [IViS] [info] Selected channel: 0 | Frequency: 1420557366.6050093 Hz | Velocity (LSRK): -32.0000000000517 km/s
# [2025-08-08 23:04:52 UTC] [IViS] [info] Extracted 626313 valid baselines.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Time for iteration 1: 0.05s, ETA: 0.00 minutes
# [2025-08-08 23:04:52 UTC] [IViS] [info] Processing file 2/5: ./data_tutorials/ivis_data/msl_mw/MW-C10_2_MW_chan_-32kms.ms
# [2025-08-08 23:04:52 UTC] [IViS] [info] Selected channel: 0 | Frequency: 1420557366.6050096 Hz | Velocity (LSRK): -32.00000000010202 km/s
# [2025-08-08 23:04:52 UTC] [IViS] [info] Extracted 1068720 valid baselines.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Time for iteration 2: 0.07s, ETA: 0.00 minutes
# [2025-08-08 23:04:52 UTC] [IViS] [info] Processing file 3/5: ./data_tutorials/ivis_data/msl_mw/MW-C10_3_MW_chan_-32kms.ms
# [2025-08-08 23:04:52 UTC] [IViS] [info] Selected channel: 0 | Frequency: 1420557366.605009 Hz | Velocity (LSRK): -32.00000000000138 km/s
# [2025-08-08 23:04:52 UTC] [IViS] [info] Extracted 1140552 valid baselines.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Time for iteration 3: 0.08s, ETA: 0.00 minutes
# [2025-08-08 23:04:52 UTC] [IViS] [info] Processing file 4/5: ./data_tutorials/ivis_data/msl_mw/MW-C10_4_MW_chan_-32kms.ms
# [2025-08-08 23:04:52 UTC] [IViS] [info] Selected channel: 0 | Frequency: 1420557366.6050093 Hz | Velocity (LSRK): -32.0000000000517 km/s
# [2025-08-08 23:04:52 UTC] [IViS] [info] Extracted 1140552 valid baselines.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Time for iteration 4: 0.08s, ETA: 0.00 minutes
# [2025-08-08 23:04:52 UTC] [IViS] [info] Processing file 5/5: ./data_tutorials/ivis_data/msl_mw/MW-C10_5_MW_chan_-32kms.ms
# [2025-08-08 23:04:52 UTC] [IViS] [info] Selected channel: 0 | Frequency: 1420557366.605009 Hz | Velocity (LSRK): -32.00000000000138 km/s
# [2025-08-08 23:04:52 UTC] [IViS] [info] Extracted 1098366 valid baselines.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Time for iteration 5: 0.07s, ETA: 0.00 minutes
# [2025-08-08 23:04:52 UTC] [IViS] [info] [Initialize Imager        ]
# [2025-08-08 23:04:52 UTC] [IViS] [info] Number of iterations to be performed by the optimizer: 20
# [2025-08-08 23:04:52 UTC] [IViS] [warning] lambda_sd = 0 - No short spacing correction (ignoring single dish data).
# [2025-08-08 23:04:52 UTC] [IViS] [warning] CUDA not available. Falling back on CPU.
# [2025-08-08 23:04:52 UTC] [IViS] [info] Nw <= 1 or None, using flat-sky NUFFT (no w-stacking).
# [2025-08-08 23:04:53 UTC] [IViS] [info] Starting optimisation (using LBFGS-B)
# [2025-08-08 23:04:53 UTC] [IViS] [info] Optimizer not bounded - Positivity == False
# [2025-08-08 23:04:59 UTC] [IViS] [info] [PID 79424] Total cost: 2.05179e+06
# [2025-08-08 23:05:05 UTC] [IViS] [info] [PID 79424] Total cost: 1.81139e+10
# [2025-08-08 23:05:07 UTC] [IViS] [info] [PID 79424] Total cost: 1.90829e+06
# [2025-08-08 23:05:10 UTC] [IViS] [info] [PID 79424] Total cost: 1.88415e+06
# [2025-08-08 23:05:12 UTC] [IViS] [info] [PID 79424] Total cost: 1.87408e+06
# [2025-08-08 23:05:15 UTC] [IViS] [info] [PID 79424] Total cost: 1.86685e+06
# [2025-08-08 23:05:19 UTC] [IViS] [info] [PID 79424] Total cost: 1.86173e+06
# [2025-08-08 23:05:21 UTC] [IViS] [info] [PID 79424] Total cost: 1.85806e+06
# [2025-08-08 23:05:24 UTC] [IViS] [info] [PID 79424] Total cost: 1.85522e+06
# [2025-08-08 23:05:27 UTC] [IViS] [info] [PID 79424] Total cost: 1.85311e+06
# [2025-08-08 23:05:31 UTC] [IViS] [info] [PID 79424] Total cost: 1.85128e+06
# [2025-08-08 23:05:34 UTC] [IViS] [info] [PID 79424] Total cost: 1.85022e+06
# [2025-08-08 23:05:37 UTC] [IViS] [info] [PID 79424] Total cost: 1.84929e+06
# [2025-08-08 23:05:39 UTC] [IViS] [info] [PID 79424] Total cost: 1.84850e+06
# [2025-08-08 23:05:43 UTC] [IViS] [info] [PID 79424] Total cost: 1.84785e+06
# [2025-08-08 23:05:46 UTC] [IViS] [info] [PID 79424] Total cost: 1.84745e+06
# [2025-08-08 23:05:50 UTC] [IViS] [info] [PID 79424] Total cost: 1.84709e+06
# [2025-08-08 23:05:53 UTC] [IViS] [info] [PID 79424] Total cost: 1.84673e+06
# [2025-08-08 23:05:56 UTC] [IViS] [info] [PID 79424] Total cost: 1.84643e+06
# [2025-08-08 23:05:58 UTC] [IViS] [info] [PID 79424] Total cost: 1.84624e+06
# [2025-08-08 23:06:00 UTC] [IViS] [info] [PID 79424] Total cost: 1.84605e+06
# [2025-08-08 23:06:02 UTC] [IViS] [info] [PID 79424] Total cost: 1.8459e+06
# [2025-08-08 23:06:02 UTC] [IViS] [warning] multiply by 2 for ASKAP.

# %%
#PLOT RESULT
fig = plt.figure(figsize=(5, 5))
ax = fig.add_axes([0.1,0.1,0.78,0.8], projection=w)
ax.set_xlabel(r"RA (deg)", fontsize=18.)
ax.set_ylabel(r"DEC (deg)", fontsize=18.)
img = ax.imshow(result*mask, vmin=-1.e-5, vmax=2.5e-5, origin="lower", cmap="gray_r")
ax.contour(pb_mean, linestyles="--", levels=[0.05, 0.2], colors=["w","w"])
colorbar_ax = fig.add_axes([0.89, 0.11, 0.02, 0.78])
cbar = fig.colorbar(img, cax=colorbar_ax)
cbar.ax.tick_params(labelsize=14.)
cbar.set_label(r"$I$ (Jy/arcsec$^{2})$", fontsize=18.)
#    plt.savefig(pathout + 'ivis_result_cloud_MeerKAT.png', format='png', bbox_inches='tight', pad_inches=0.02, dpi=400)

# %%
# Get tapper for apodization
tapper = fourier.apodize(0.97, shape)
# Reove the mean
field_zm = result - np.mean(result)
# Apply apodization function
field_zm_apod = field_zm * tapper

# Compute the 1D P(k)
ks, sps1d_s = fourier.powspec(field_zm_apod, reso=(target_header["CDELT2"]*u.deg).to(u.arcmin).value)

# %% [markdown]
# ## Rescaling to match amplitude
#
# For reasons that I don't fully understand, the noise realization obtained from synthetizing random noise with SIGMA from the ms doesn't yield the right scaling.
# Here this scaling factor is being inferred at ks > kmin_fit (in arcmin).

# %%
# Assume ks, sps1d_s, and sps1d_n are already defined

# ---- STEP 1: Define a fitting range (e.g., high-k range) ----
kmin_fit = 0.7  # in arcmin^{-1}, adjust as appropriate
fit_mask = ks > kmin_fit

# ---- STEP 2: Fit scaling factor ----
numerator = np.sum(sps1d_s[fit_mask] * sps1d_n[fit_mask])
denominator = np.sum(sps1d_n[fit_mask] ** 2)
scaling_factor = numerator / denominator

print(f"Best-fit noise scaling factor: {scaling_factor:.4f}")

# ---- STEP 3: Plot ----
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.set_xscale('log')
ax.set_yscale('log')

ax.plot(ks, sps1d_s, "-k", label="Signal")
ax.plot(ks, sps1d_n * scaling_factor, "-m", label=f"Noise * {scaling_factor:.2f}")

ax.set_xlabel(r"$k$ (arcmin$^{-1}$)", fontsize=16)
ax.set_ylabel(r"$P(k)$ [(Jy/arcsec$^2$)$^2$]", fontsize=16)
ax.xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax.legend()
# Out:
# Best-fit noise scaling factor: 0.3476

# %% [markdown]
# Here again you can change the regularization strength to see how it both impact the imaged signal and synthetized noise passed through the IViS.
